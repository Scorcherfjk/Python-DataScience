# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y = [60,90,55,95,60,80]
plt.ylabel("calificacion promedio")

x = [1,6,2,7,3,4]
plt.xlabel("periodo")

plt.grid(True)

plt.scatter(x,y)
plt.show()

# %%
y = [1.1,1.2,1.3,1.4,1.5]
plt.ylabel("altura")

x = [5,6,8,10,12]
plt.xlabel("edad")

plt.grid(True)

plt.scatter(x,y)
plt.show()

# %%
x = [32.5,20,15,35,10,37.5]
plt.xlabel("altura")

y = [5,4,2,8,1.5,8.5]
plt.ylabel("longitud del petalo")

plt.grid(True)

plt.scatter(x,y)
plt.show()

# %%
y = [4.25,5.0,5.75,6.25,6.75,7.0]
plt.ylabel("peso")

x = [1,2,3,4,5,6]
plt.xlabel("edad")

plt.grid(True)

plt.scatter(x,y)
plt.show()

# %%
y = [1.0,2.5,5.25,10.75,11.25]
plt.ylabel("luz solar")

x = [0,2,4,6,8]
plt.xlabel("cambio en circunferencia")

plt.grid(True)

plt.scatter(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6]
plt.ylabel("distancia")

y = [5.1,11.8,17.7,25.2,33.0,41.9]
plt.xlabel("tiempo")

plt.grid(True)

plt.scatter(x,y)
plt.show()
